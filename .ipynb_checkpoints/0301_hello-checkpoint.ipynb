# %%
import pandas as pd

df = pd.read_csv('total_new.csv')

df.head(10)
# Out:
#    sn1_holding+filling  sn1_max  sn2_holding+filling    sn2_max  \
# 0           253.857916     67.6           215.302543  63.127194
# 1           248.486515     67.6           222.867030  63.846190
# 2           253.035371     67.6           225.674294  64.385367
# 3           291.171891     78.0           252.745037  73.944439
# 4           285.213678     78.0           266.206756  75.165153
# 5           295.378728     78.0           265.193835  75.547192
# 6           328.482358     88.4           293.428123  85.226073
# 7           321.840375     88.4           306.786805  86.804827
# 8           333.857679     88.4           306.512808  87.242230
# 9           260.434022     67.6           222.549254  63.325143
#
#    sn3_holding+filling    sn3_max  sn4_holding+filling    sn4_max
# 0           138.882202  55.832318           117.927712  52.915555
# 1           144.324803  57.822824           122.489817  54.632269
# ...

# %%
temp = df[['sn1_holding+filling', 'sn1_max']]
temp
# Out:
#      sn1_holding+filling  sn1_max
# 0             253.857916     67.6
# 1             248.486515     67.6
# 2             253.035371     67.6
# 3             291.171891     78.0
# 4             285.213678     78.0
# ..                   ...      ...
# 130           280.796320     78.0
# 131           281.142275     78.0
# 132           326.128996     88.4
# 133           317.075547     88.4
# 134           316.465972     88.4
#
# [135 rows x 2 columns]

# %%
Type = temp.groupby(['sn1_holding+filling'])['sn1_max'].sum().reset_index()
Type['class'] = 1
Type
# Out:
#      sn1_holding+filling  sn1_max  class
# 0             244.514026     67.6      1
# 1             244.725153     67.6      1
# 2             245.044718     67.6      1
# 3             245.364264     67.6      1
# 4             245.682081     67.6      1
# ..                   ...      ...    ...
# 130           336.651093     88.4      1
# 131           336.861362     88.4      1
# 132           337.274391     88.4      1
# 133           337.670095     88.4      1
# 134           338.032707     88.4      1
#
# [135 rows x 3 columns]
